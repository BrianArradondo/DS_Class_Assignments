# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("bikeshare_train - bikeshare_train.csv")
df2 = df.copy()
df.head(10)
# Out:
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-01 0:00:00       1        0           0        1   9.84  14.395
# 1  2011-01-01 1:00:00       1        0           0        1   9.02  13.635
# 2  2011-01-01 2:00:00       1        0           0        1   9.02  13.635
# 3  2011-01-01 3:00:00       1        0           0        1   9.84  14.395
# 4  2011-01-01 4:00:00       1        0           0        1   9.84  14.395
# 5  2011-01-01 5:00:00       1        0           0        2   9.84  12.880
# 6  2011-01-01 6:00:00       1        0           0        1   9.02  13.635
# 7  2011-01-01 7:00:00       1        0           0        1   8.20  12.880
# 8  2011-01-01 8:00:00       1        0           0        1   9.84  14.395
# 9  2011-01-01 9:00:00       1        0           0        1  13.12  17.425
#
#    humidity  windspeed  casual  registered  count
# 0        81     0.0000       3          13     16
# ...

# %%
df = df.drop(columns=["casual","registered"])
df.head(10)
# Out:
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-01 0:00:00       1        0           0        1   9.84  14.395
# 1  2011-01-01 1:00:00       1        0           0        1   9.02  13.635
# 2  2011-01-01 2:00:00       1        0           0        1   9.02  13.635
# 3  2011-01-01 3:00:00       1        0           0        1   9.84  14.395
# 4  2011-01-01 4:00:00       1        0           0        1   9.84  14.395
# 5  2011-01-01 5:00:00       1        0           0        2   9.84  12.880
# 6  2011-01-01 6:00:00       1        0           0        1   9.02  13.635
# 7  2011-01-01 7:00:00       1        0           0        1   8.20  12.880
# 8  2011-01-01 8:00:00       1        0           0        1   9.84  14.395
# 9  2011-01-01 9:00:00       1        0           0        1  13.12  17.425
#
#    humidity  windspeed  count
# 0        81     0.0000     16
# 1        80     0.0000     40
# 2        80     0.0000     32
# ...

# %%
df["datetime"] = pd.to_datetime(df["datetime"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  datetime64[ns]
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   count       10886 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(6)
# memory usage: 850.6 KB

# %%
df["month (name)"] = df["datetime"].dt.month_name()
df["day of week(name)"] = df["datetime"].dt.day_name()
df["hour of day"] = df["datetime"].dt.hour.astype(dtype="object")

df.head(10)
# Out:
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1   9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1   9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1   9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1   9.84  14.395
# 5 2011-01-01 05:00:00       1        0           0        2   9.84  12.880
# 6 2011-01-01 06:00:00       1        0           0        1   9.02  13.635
# 7 2011-01-01 07:00:00       1        0           0        1   8.20  12.880
# 8 2011-01-01 08:00:00       1        0           0        1   9.84  14.395
# 9 2011-01-01 09:00:00       1        0           0        1  13.12  17.425
#
#    humidity  windspeed  count month (name) day of week(name) hour of day
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   datetime           10886 non-null  datetime64[ns]
#  1   season             10886 non-null  int64
#  2   holiday            10886 non-null  int64
#  3   workingday         10886 non-null  int64
#  4   weather            10886 non-null  int64
#  5   temp               10886 non-null  float64
#  6   atemp              10886 non-null  float64
#  7   humidity           10886 non-null  int64
#  8   windspeed          10886 non-null  float64
#  9   count              10886 non-null  int64
#  10  month (name)       10886 non-null  object
#  11  day of week(name)  10886 non-null  object
#  12  hour of day        10886 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(6), object(3)
# memory usage: 1.1+ MB

# %%
df[['temp', 'atemp']] = df[['temp', 'atemp']].apply(lambda x: x * 9/5 + 32)

# %%
df = df.drop(columns=["datetime","season"])
df.head(10)
# Out:
#    holiday  workingday  weather    temp   atemp  humidity  windspeed  count  \
# 0        0           0        1  49.712  57.911        81     0.0000     16
# 1        0           0        1  48.236  56.543        80     0.0000     40
# 2        0           0        1  48.236  56.543        80     0.0000     32
# 3        0           0        1  49.712  57.911        75     0.0000     13
# 4        0           0        1  49.712  57.911        75     0.0000      1
# 5        0           0        2  49.712  55.184        75     6.0032      1
# 6        0           0        1  48.236  56.543        80     0.0000      2
# 7        0           0        1  46.760  55.184        86     0.0000      3
# 8        0           0        1  49.712  57.911        75     0.0000      8
# 9        0           0        1  55.616  63.365        76     0.0000     14
#
#   month (name) day of week(name) hour of day
# 0      January          Saturday           0
# ...

# %% [markdown]
# - Create a new column, 'temp_variance' which shows how much warmer or colder the current temperature ('temp') is than the average temperate for that day of the year ('atemp').  If the current temperature is warmer than average ('atemp'), the value in 'temp_variance' should be positive.
# Drop the 'atemp' column.

# %%
df["temp_changes"] = df["temp"] - df["atemp"]
print(df.info())
df.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   holiday            10886 non-null  int64
#  1   workingday         10886 non-null  int64
#  2   weather            10886 non-null  int64
#  3   temp               10886 non-null  float64
#  4   atemp              10886 non-null  float64
#  5   humidity           10886 non-null  int64
#  6   windspeed          10886 non-null  float64
#  7   count              10886 non-null  int64
#  8   month (name)       10886 non-null  object
#  9   day of week(name)  10886 non-null  object
#  10  hour of day        10886 non-null  object
#  11  temp_changes       10886 non-null  float64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 1020.7+ KB
# None
#        holiday  workingday  weather    temp   atemp  humidity  windspeed  \
# ...

# %%
# df["temp_variance"] = temp
df["temp_variance"] = df["temp_changes"].apply(lambda x: "warmer" if x > 0 else "colder")
df.head(10)
# Out:
#    holiday  workingday  weather    temp   atemp  humidity  windspeed  count  \
# 0        0           0        1  49.712  57.911        81     0.0000     16
# 1        0           0        1  48.236  56.543        80     0.0000     40
# 2        0           0        1  48.236  56.543        80     0.0000     32
# 3        0           0        1  49.712  57.911        75     0.0000     13
# 4        0           0        1  49.712  57.911        75     0.0000      1
# 5        0           0        2  49.712  55.184        75     6.0032      1
# 6        0           0        1  48.236  56.543        80     0.0000      2
# 7        0           0        1  46.760  55.184        86     0.0000      3
# 8        0           0        1  49.712  57.911        75     0.0000      8
# 9        0           0        1  55.616  63.365        76     0.0000     14
#
#   month (name) day of week(name) hour of day  temp_changes temp_variance
# ...

# %% [markdown]
# # Create a model for Bike users

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import make_column_selector,make_column_transformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn import set_config
set_config(display='diagram')
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression

# Regression Metrics
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

from IPython.core.display import clear_output
# Out:
# C:\Users\obsid\AppData\Local\Temp\ipykernel_33272\2810762909.py:20: DeprecationWarning: Importing clear_output from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import clear_output

# %%
## Create a function to take the true and predicted values
## and print MAE, MSE, RMSE, and R2 metrics for a model
def eval_regression(y_true, y_pred, name='model'):
  """Takes true targets and predictions from a regression model and prints
  MAE, MSE, RMSE, AND R2 scores
  Set 'name' to name of model and 'train' or 'test' as appropriate"""
  mae = mean_absolute_error(y_true, y_pred)
  mse = mean_squared_error(y_true, y_pred)
  rmse = np.sqrt(mse)
  r2 = r2_score(y_true, y_pred)

  print(f'{name} Scores')
  print(f'MAE: {mae:,.4f} \nMSE: {mse:,.4f} \nRMSE: {rmse:,.4f} \nR2: {r2:.4f}\n')

# %% [markdown]
# ## Import the Model

# %%
from sklearn.ensemble import RandomForestRegressor # This line imports Random Forest Regressor

# %%
df2.info() # This column tells me dataset size and object type, missing values, etc.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %%
print(f" There are {df2.duplicated().sum()} duplicates in our dataset")
# Out:
#  There are 0 duplicates in our dataset

# %%
print(f"There are {df2.isna().sum()} missing values in our dataset")
# Out:
# There are datetime      0
# season        0
# holiday       0
# workingday    0
# weather       0
# temp          0
# atemp         0
# humidity      0
# windspeed     0
# casual        0
# registered    0
# count         0
# dtype: int64 missing values in our dataset

# %%
df2.nunique() #
# Out:
# datetime      10886
# season            4
# holiday           2
# workingday        2
# weather           4
# temp             49
# atemp            60
# humidity         89
# windspeed        28
# casual          309
# registered      731
# count           822
# dtype: int64

# %%
df2 = df2.drop(columns=["casual","registered"]) # dropping unnecessary columns
df2.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 0:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 1:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 2:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 3:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 4:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  count
# 0        81        0.0     16
# 1        80        0.0     40
# 2        80        0.0     32
# 3        75        0.0     13
# 4        75        0.0      1

# %%
df2.describe(include="all")
# Out:
#                   datetime        season       holiday    workingday  \
# count                10886  10886.000000  10886.000000  10886.000000
# unique               10886           NaN           NaN           NaN
# top     2011-01-01 0:00:00           NaN           NaN           NaN
# freq                     1           NaN           NaN           NaN
# mean                   NaN      2.506614      0.028569      0.680875
# std                    NaN      1.116174      0.166599      0.466159
# min                    NaN      1.000000      0.000000      0.000000
# 25%                    NaN      2.000000      0.000000      0.000000
# 50%                    NaN      3.000000      0.000000      1.000000
# 75%                    NaN      4.000000      0.000000      1.000000
# max                    NaN      4.000000      1.000000      1.000000
#
#              weather         temp         atemp      humidity     windspeed  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   holiday            10886 non-null  int64
#  1   workingday         10886 non-null  int64
#  2   weather            10886 non-null  int64
#  3   temp               10886 non-null  float64
#  4   atemp              10886 non-null  float64
#  5   humidity           10886 non-null  int64
#  6   windspeed          10886 non-null  float64
#  7   count              10886 non-null  int64
#  8   month (name)       10886 non-null  object
#  9   day of week(name)  10886 non-null  object
#  10  hour of day        10886 non-null  object
#  11  temp_changes       10886 non-null  float64
#  12  temp_variance      10886 non-null  object
# dtypes: float64(4), int64(5), object(4)
# memory usage: 1.1+ MB

# %% [markdown]
# ## Format for ML and Train Test Split (Unengineered Data Set)

# %%
X = df2.drop(columns="count") # These lines of code split our data
y = df2["count"]
X_train, X_test, y_train,y_test = train_test_split(X, y, random_state =42)

# %% [markdown]
# ### Instantiate transformers

# %%
scaler =StandardScaler()
ohe = OneHotEncoder(handle_unknown="ignore")

# %% [markdown]
# ### Instantiate the Column Selectors

# %%
# Instantiate the column selectors
num_selector = make_column_selector(dtype_include="number")
cat_selector = make_column_selector(dtype_include="object")

# %% [markdown]
# ### Match Transformers with Columns

# %%
num_tuple = (scaler, num_selector)
cat_tuple = (ohe, cat_selector)

# %% [markdown]
# ### Instantiate Column Transformer

# %%
preprocessor = make_column_transformer(num_tuple, 
                                       cat_tuple, 
                                       remainder='drop',
                                       verbose_feature_names_out=False)

# %% [markdown]
# ## Fit the Preprocessor

# %%
preprocessor.fit(X_train)
# Out:
# ColumnTransformer(transformers=[('standardscaler', StandardScaler(),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x0000025FF3D3E760>),
#                                 ('onehotencoder',
#                                  OneHotEncoder(handle_unknown='ignore'),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x0000025FF3D263A0>)],
#                   verbose_feature_names_out=False)

# %% [markdown]
# ## Fit the Model

# %%
## Create an instance of the model
rf2 = RandomForestRegressor()

## Create a model pipeline
rf_pipe2 = make_pipeline(preprocessor, rf2)

## Fit the model
rf_pipe2.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('standardscaler',
#                                                   StandardScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x0000025FF3D3E760>),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x0000025FF3D263A0>)],
#                                    verbose_feature_names_out=False)),
#                 ('randomforestregressor', RandomForestRegressor())])

# %% [markdown]
# ## Evaluate Model Metrics

# %%
train_preds2 = rf_pipe2.predict(X_train)
test_preds2 = rf_pipe2.predict(X_test)

eval_regression(y_train, train_preds2, name="Random Forest Train")
eval_regression(y_test, test_preds2, name="Random Forest Test")
# Out:
# Random Forest Train Scores
# MAE: 37.7566
# MSE: 3,400.2137
# RMSE: 58.3114
# R2: 0.8964
#
# Random Forest Test Scores
# MAE: 101.5159
# MSE: 24,861.3474
# RMSE: 157.6748
# R2: 0.2424

# %% [markdown]
# # Format for ML and Train Test Split (Engineered Data Set)

# %%
X = df.drop(columns="count") # These lines of code split our data
y = df["count"]
X_train, X_test, y_train,y_test = train_test_split(X, y, random_state =42)

# %% [markdown]
# ## Instantiate transformers

# %%
scaler =StandardScaler()
ohe = OneHotEncoder(handle_unknown="ignore")

# %% [markdown]
# ## Instantiate the Column Selectors

# %%
# Instantiate the column selectors
num_selector = make_column_selector(dtype_include="number")
cat_selector = make_column_selector(dtype_include="object")

# %% [markdown]
# ## Match Transformers with Columns

# %%
num_tuple = (scaler, num_selector)
cat_tuple = (ohe, cat_selector)

# %% [markdown]
# ## Instantiate Column Transformer

# %%
preprocessor = make_column_transformer(num_tuple, 
                                       cat_tuple, 
                                       remainder='drop',
                                       verbose_feature_names_out=False)

# %% [markdown]
# ## Fit the Preprocessor

# %%
preprocessor.fit(X_train)
# Out:
# ColumnTransformer(transformers=[('standardscaler', StandardScaler(),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x0000025FF3D264F0>),
#                                 ('onehotencoder',
#                                  OneHotEncoder(handle_unknown='ignore'),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x0000025FEFF57DF0>)],
#                   verbose_feature_names_out=False)

# %% [markdown]
# ## Fit the Model

# %%
## Create an instance of the model
rf = RandomForestRegressor()

## Create a model pipeline
rf_pipe = make_pipeline(preprocessor, rf)

## Fit the model
rf_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('standardscaler',
#                                                   StandardScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x0000025FF3D264F0>),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x0000025FEFF57DF0>)],
#                                    verbose_feature_names_out=False)),
#                 ('randomforestregressor', RandomForestRegressor())])

# %% [markdown]
# ## Evaluate Model Metrics

# %%
train_preds = rf_pipe.predict(X_train)
test_preds = rf_pipe.predict(X_test)

eval_regression(y_train, train_preds, name="Random Forest Train")
eval_regression(y_test, test_preds, name="Random Forest Test")
# Out:
# Random Forest Train Scores
# MAE: 18.3072
# MSE: 777.2522
# RMSE: 27.8792
# R2: 0.9763
#
# Random Forest Test Scores
# MAE: 48.5664
# MSE: 5,286.5175
# RMSE: 72.7084
# R2: 0.8389

# %% [markdown]
# # The Feature Engineering Choices have definitely improved the Model's ability to predict the "count" Target.
