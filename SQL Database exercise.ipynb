# %% [markdown]
# # Imports

# %%
# imports
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ## Read in the Data as Pandas Dataframe

# %%
school_df = pd.read_csv("School_Details.csv")

# %%
school_df.head(10)
# Out:
#   DistrictName EstablishmentCode  \
# 0         East             S0169
# 1         East             S0099
# 2         East             S0848
# 3         East             S0190
# 4         East             S0111
# 5         East             S0856
# 6         East             S0870
# 7         East             S0157
# 8         East             S0876
# 9         East             S0164
#
#                                    EstablishmentName   BRCName  \
# 0               BUDANG GOVERNMENT PRIMARY SCHOOL (E)  Duga Brc
# 1  CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL  Duga Brc
# 2              CENTRAL POINT ACADEMY, CENTRAL PENDAM  Duga Brc
# 3      CHEURIBOTEY GOVERNMENT JUNIOR HIGH SCHOOL (E)  Duga Brc
# 4                   DUGA GOVERNMENT SECONDARY SCHOOL  Duga Brc
# 5                   EASWARAMMA SAI GURUKOOL ACCADEMY  Duga Brc
# 6                ETERNAL ENGLISH SCHOOL, WEST PENDAM  Duga Brc
# 7               KHANI GOAN GOVERNMENT PRIMARY SCHOOL  Duga Brc
# ...

# %%
school_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1249 entries, 0 to 1248
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   DistrictName                1249 non-null   object
#  1   EstablishmentCode           1249 non-null   object
#  2   EstablishmentName           1249 non-null   object
#  3   BRCName                     1249 non-null   object
#  4   CRCName                     1249 non-null   object
#  5   SchoolLevel                 1246 non-null   object
#  6   ManagementName              1246 non-null   object
#  7   LocalityHabitation          1221 non-null   object
#  8   SubdivisionName             1241 non-null   object
#  9   ConstituencyName            1249 non-null   object
#  10  RevenueBlockName            1249 non-null   object
#  11  CivicBodyName               1249 non-null   object
#  12  WardName                    1249 non-null   object
# ...

# %% [markdown]
# ## Create a SQLite Database

# %% [markdown]
# - SQLite  is just one example of a database

# %%
# create sqlite engine for a database called schools
engine = create_engine("sqlite:///schools.db", echo=True)
# create connection to engine
conn = engine.connect()

# %%
# add the dataframe as a table in sqlite

#sqlite_table = "school_details"
#school_df.to_sql(sqlite_table,conn,if_exists="fail")

# %% [markdown]
# ## Add a Table to the Database

# %%
sql = "SELECT LOWESTCLASS FROM school_details Limit 5;"
pd.read_sql_query(sql,engine)
# Out:
# 2023-05-24 16:37:04,938 INFO sqlalchemy.engine.Engine SELECT LOWESTCLASS FROM school_details Limit 5;
# 2023-05-24 16:37:04,939 INFO sqlalchemy.engine.Engine [raw sql] ()
#   LowestClass
# 0     Class 1
# 1     Class 1
# 2     Class 1
# 3     Class 1
# 4     Class 1

# %%
sql = "SELECT `CRCDistance (in Km)` FROM school_details;"
pd.read_sql_query(sql,engine)
# Out:
# 2023-05-24 16:37:04,953 INFO sqlalchemy.engine.Engine SELECT `CRCDistance (in Km)` FROM school_details;
# 2023-05-24 16:37:04,954 INFO sqlalchemy.engine.Engine [raw sql] ()
#       CRCDistance (in Km)
# 0                     8.0
# 1                     0.0
# 2                     1.5
# 3                     6.0
# 4                     0.0
# ...                   ...
# 1244                  4.0
# 1245                  2.0
# 1246                  0.0
# 1247                  3.0
# 1248                  7.0
#
# [1249 rows x 1 columns]

# %%
sql = "SELECT EstablishmentName FROM school_details WHERE SchoolLevel = 'SSS';"

pd.read_sql_query(sql,engine)
# Out:
# 2023-05-24 16:37:04,969 INFO sqlalchemy.engine.Engine SELECT EstablishmentName FROM school_details WHERE SchoolLevel = 'SSS';
# 2023-05-24 16:37:04,970 INFO sqlalchemy.engine.Engine [raw sql] ()
#                                     EstablishmentName
# 0   CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL
# 1           RANGPO GOVERNMENT SENIOR SECONDARY SCHOOL
# 2         EAST POINT SENIOR SECONDARY SCHOOL, SINGTAM
# 3    ASSAM LINGZEY GOVERNMENT SENIOR SECONDARY SCHOOL
# 4                 LITTLE ANGEL ENGLISH SCHOOL, NANDOK
# ..                                                ...
# 79          SORENG GOVERNMENT SENIOR SECONDARY SCHOOL
# 80          THARPU GOVERNMENT SENIOR SECONDARY SCHOOL
# 81      KHECHUPERI GOVERNMENT SENIOR SECONDARY SCHOOL
# 82                    EKLAVYA MODEL RESIDENTAL SCHOOL
# 83       TASHIDING GOVERNMENT SENIOR SECONDARY SCHOOL
#
# [84 rows x 1 columns]

# %%
sql = "SELECT ManagementName From school_details WHERE SubdivisionName = 'Gangtok';"
pd.read_sql_query(sql,engine)
# Out:
# 2023-05-24 16:37:04,986 INFO sqlalchemy.engine.Engine SELECT ManagementName From school_details WHERE SubdivisionName = 'Gangtok';
# 2023-05-24 16:37:04,986 INFO sqlalchemy.engine.Engine [raw sql] ()
#         ManagementName
# 0          State Govt.
# 1          State Govt.
# 2    Private (Unaided)
# 3          State Govt.
# 4          State Govt.
# ..                 ...
# 256  Private (Unaided)
# 257        State Govt.
# 258        State Govt.
# 259        State Govt.
# 260        State Govt.
#
# [261 rows x 1 columns]

# %%
sql = "SELECT Website, WardName, ManagementName FROM school_details;"
pd.read_sql_query(sql,engine)
# Out:
# 2023-05-24 16:37:04,999 INFO sqlalchemy.engine.Engine SELECT Website, WardName, ManagementName FROM school_details;
# 2023-05-24 16:37:05,000 INFO sqlalchemy.engine.Engine [raw sql] ()
#                                         Website  \
# 0                                          None
# 1                                          None
# 2     www.facebook.com/khanalkeshav (Group-CPA)
# 3                                          None
# 4                                          None
# ...                                         ...
# 1244                                       None
# 1245                                       None
# 1246                                       None
# 1247                                       None
# 1248                                       None
#
#                                         WardName     ManagementName
# 0                                         Sajong        State Govt.
# ...

# %%
sql = """SELECT EstablishmentName, PostofficeName
FROM school_details
WHERE EstablishmentName LIKE 'New%'
"""
pd.read_sql_query(sql, engine)
# Out:
# 2023-05-24 16:37:05,016 INFO sqlalchemy.engine.Engine SELECT EstablishmentName, PostofficeName
# FROM school_details
# WHERE EstablishmentName LIKE 'New%'
#
# 2023-05-24 16:37:05,017 INFO sqlalchemy.engine.Engine [raw sql] ()
#                             EstablishmentName PostOfficeName
# 0         NEW GARDEN BOARDING SCHOOL (SAJONG)   Upper Pendam
# 1                         NEW HORIZON ACADEMY         Rongpo
# 2                NEW VISION ACADEMY, MAJHITAR       Majhitar
# 3           NEW VISION ACADEMY, CHOTA SINGTAM  Assam Lingzey
# 4         NEW GARDEN BOARDING SCHOOL, SINGTAM        Singtam
# 5                 NEW BUDS ACADEMY, JORETHANG     Naya Bazar
# 6              NEW LIGHT ACADEMY, ASSANGTHANG    Assangthang
# 7                    NEW LIGHT ACADEMY NAMCHI         Namchi
# 8                 NEW STEPS ACADEMY, NAMTHANG       Namthang
# 9   NEW RAYS ACADEMY DEYTHANG BUSTY S. SIKKIM       Ravangla
# 10                    NEW HOPE ACADEMY, SIKIP            Vok
# ...
